# %% [markdown]
# <a href="https://colab.research.google.com/github/SMayurgavali/PROJECT/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/udemy_courses.csv")

# %%
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.shape
# Out:
# (3678, 12)

# %%
# what are the different subjects for which is udemy is offering courses ?

# %%
data.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
# which subject has the maximum number of courses ?

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
# show all the courses which are free of cost ?

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data[data.is_paid == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
# show all the courses which are paid ?

# %%
data[data.is_paid == True]
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
# what are the top selling courses ?

# %%
x = data.sort_values("num_subscribers", ascending = False)
x.head(5)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# 2783  https://www.udemy.com/build-your-first-website...    False      0
# 3232  https://www.udemy.com/the-complete-web-develop...     True    200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
# which are least selling courses ?

# %%
x = data.sort_values("num_subscribers", ascending = True)
x.head(1)
# Out:
#      course_id          course_title  \
# 885    1032648  beginning accounting
#
#                                              url  is_paid  price  \
# 885  https://www.udemy.com/beginning_accounting/     True     20
#
#      num_subscribers  num_reviews  num_lectures               level  \
# 885                0            0            12  Intermediate Level
#
#      content_duration   published_timestamp           subject
# 885          0.633333  2016-12-26T16:52:47Z  Business Finance

# %%
# show all courses of graphic design where the price is below 100 ?

# %%
a= data[(data.subject == 'Graphic Design') & (data.price < 100)]

# %%
a.head()
# Out:
#       course_id                                       course_title  \
# 1196    1197206                         Illustrator CC MasterClass
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1202      28556              Discover How to Draw and paint Comics
# 1203     317278  Typographic Logos: Typography and Lettering fo...
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...
#
#                                                     url  is_paid  price  \
# 1196  https://www.udemy.com/illustrator-cc-masterclass/     True     95
# 1198         https://www.udemy.com/merchbyamazondesign/     True     20
# 1202     https://www.udemy.com/learn-to-draw-and-paint/     True     65
# 1203  https://www.udemy.com/typographic-logos-typogr...     True     25
# 1204  https://www.udemy.com/photoshop-knights-become...     True     20
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
# list out all the courses that are related with Business Finance ?

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
a =data[data.course_title.str.contains("Business Finance")]
a.head(5)
# Out:
#       course_id                                       course_title  \
# 236      267984  Accounting 101: Learn Business Finance Forecas...
# 272       46927                         Basics of Business Finance
# 1158     692268  Learn Business Finance: Win more work as a Bus...
#
#                                                     url  is_paid  price  \
# 236   https://www.udemy.com/cashflow-forecasting-mad...     True     95
# 272   https://www.udemy.com/basics-of-business-finance/     True     30
# 1158  https://www.udemy.com/essential-business-finan...     True     20
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 236              1730           12            12      All Levels
# 272              4855           64            24  Beginner Level
# 1158              741            4            22  Beginner Level
#
#       content_duration   published_timestamp           subject
# 236                1.5  2014-07-24T15:20:39Z  Business Finance
# ...

# %%
data.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)
